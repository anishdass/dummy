# %%
from googleapiclient.discovery import build
import re
from datetime import timedelta

# %%
api_key = 'AIzaSyDRoP7iVH6MX85XKeeTJwtTQpIV5_U2f1w'

# %%
youtube = build('youtube', 'v3', developerKey=api_key)

# %%
request = youtube.channels().list(
    part='statistics',
    forUsername='MrBeast6000'
)

# %%
response = request.execute()
response
# Out:
# {'etag': 'dim5E6zYd4rCkJ4sbSfnSNKZXJ8',
#  'items': [{'etag': 'zJj6V2w4ZAKyDivZNi-kyIs9ufc',
#    'id': 'UCX6OQ3DkcsbYNE6H8uQQuVA',
#    'kind': 'youtube#channel',
#    'statistics': {'hiddenSubscriberCount': False,
#     'subscriberCount': '64200000',
#     'videoCount': '706',
#     'viewCount': '11328143033'}}],
#  'kind': 'youtube#channelListResponse',
#  'pageInfo': {'resultsPerPage': 5, 'totalResults': 1}}

# %%
request2 = youtube.playlists().list(
    part = 'contentDetails, snippet',
    channelId = 'UCX6OQ3DkcsbYNE6H8uQQuVA',
    maxResults = 50
)

# %%
response2 = request2.execute()

# %%
playlist_ids = [item['id'] for item in response2['items']]

# %%
playlist_ids
# Out:
# ['PLoSWVnSA9vG-9NTwPXTRLOU4Ltec7fGkg',
#  'PLoSWVnSA9vG9XLhjiMt6ZReflljY7-B2c',
#  'PLoSWVnSA9vG9QbL9nV1pisgWCemD0UFnZ',
#  'PLoSWVnSA9vG9znrCdXo74jUKDqucZhA9-',
#  'PLoSWVnSA9vG_4nlMUZHUyrjLyZ0Qcp5VL',
#  'PLoSWVnSA9vG-AuFOoSY4R3zNPCbQDr5wY',
#  'PLoSWVnSA9vG-6geT_u92P9ttBfRLVFhLH']

# %%
responses = []
for id in playlist_ids:
  request = youtube.playlistItems().list(
    part = 'contentDetails',
    playlistId=id,
    maxResults = 50
    )
  response = request.execute()
  responses.append(response)

# %%
video_ids=[]
for response in responses:
  for item in response['items']:
    video_ids.append(item['contentDetails']['videoId'])

# %%
request3 = youtube.videos().list(
    part = 'contentDetails',
    id = ','.join(video_ids)
)

# %%
video_ids1 = video_ids[:50]
video_ids2 = video_ids[50:]

# %%
request3 = youtube.videos().list(
    part = 'contentDetails',
    id = ','.join(video_ids1)
)
request4 = youtube.videos().list(
    part = 'contentDetails',
    id = ','.join(video_ids2)
)

# %%
response3 = request3.execute()
response4 = request4.execute()

# %%
response3['items']
# Out:
# [{'contentDetails': {'caption': 'false',
#    'contentRating': {},
#    'definition': 'hd',
#    'dimension': '2d',
#    'duration': 'PT10M13S',
#    'licensedContent': True,
#    'projection': 'rectangular'},
#   'etag': '7vEJhI2FqLuy_qkDv12weSQ0ASU',
#   'id': '5V2B28OqfqM',
#   'kind': 'youtube#video'},
#  {'contentDetails': {'caption': 'false',
#    'contentRating': {},
#    'definition': 'hd',
#    'dimension': '2d',
#    'duration': 'PT11M37S',
#    'licensedContent': True,
#    'projection': 'rectangular'},
#   'etag': 'zB5Zg3WzbXAM8AYpxShCJOl3T5Q',
#   'id': 'FbM1yi4mMMc',
#   'kind': 'youtube#video'},
#  {'contentDetails': {'caption': 'false',
#    'contentRating': {},
#    'definition': 'hd',
#    'dimension': '2d',
#    'duration': 'PT22M16S',
#    'licensedContent': True,
#    'projection': 'rectangular'},
#   'etag': 'CwzlfIyIIgcMVaO8y_YUONOQ-JE',
#   'id': 'NkE0AMGzpJY',
#   'kind': 'youtube#video'},
#  {'contentDetails': {'caption': 'false',
#    'contentRating': {},
# ...

# %%
hours_pattern = re.compile(r'\d+H')
minutes_pattern = re.compile(r'\d+M')
seconds_pattern = re.compile(r'\d+S')

# %%
for item in response3['items']:
  duration = item['contentDetails']['duration']
  hours = hours_pattern.search(duration)
  minutes = minutes_pattern.search(duration)
  seconds = seconds_pattern.search(duration)

  hours = int(minutes.group(0)[:-1]) if hours else 0
  minutes = int(minutes.group(0)[:-1]) if minutes else 0
  seconds = int(seconds.group(0)[:-1]) if seconds else 0

  video_duration = timedelta(
      hours = hours,
      minutes = minutes,
      seconds = seconds
      ).total_seconds()

  print(hours, minutes, seconds, video_duration)
# Out:
# 0 10 13 613.0
# 0 11 37 697.0
# 0 22 16 1336.0
# 0 8 3 483.0
# 0 11 9 669.0
# 0 13 56 836.0
# 0 14 59 899.0
# 0 14 50 890.0
# 0 15 9 909.0
# 0 15 38 938.0
# 0 13 52 832.0
# 0 14 53 893.0
# 0 7 23 443.0
# 0 17 3 1023.0
# 0 13 2 782.0
# 0 15 56 956.0
# 0 15 3 903.0
# 0 15 42 942.0
# 0 15 17 917.0
# 0 13 9 789.0
# 0 16 39 999.0
# 0 13 22 802.0
# 0 16 57 1017.0
# 0 14 4 844.0
# 0 16 56 1016.0
# 0 14 20 860.0
# 0 13 44 824.0
# 0 15 19 919.0
# 0 17 51 1071.0
# 0 15 24 924.0
# 0 14 58 898.0
# 0 14 18 858.0
# 0 14 29 869.0
# 0 16 57 1017.0
# 0 14 2 842.0
# 0 15 46 946.0
# 0 12 42 762.0
# 0 17 3 1023.0
# 0 16 39 999.0
# 0 16 56 1016.0
# 0 15 9 909.0
# 0 12 29 749.0
# 0 16 4 964.0
# 0 16 32 992.0
# 0 16 36 996.0
# 0 13 44 824.0
# 0 19 47 1187.0
# 0 18 8 1088.0
# 0 14 58 898.0
# 0 24 39 1479.0

# %%
for item in response4['items']:
  duration = item['contentDetails']['duration']
  hours = hours_pattern.search(duration)
  minutes = minutes_pattern.search(duration)
  seconds = seconds_pattern.search(duration)

  hours = int(minutes.group(0)[:-1]) if hours else 0
  minutes = int(minutes.group(0)[:-1]) if minutes else 0
  seconds = int(seconds.group(0)[:-1]) if seconds else 0

  video_duration = timedelta(
      hours = hours,
      minutes = minutes,
      seconds = seconds
      ).total_seconds()

  print(hours, minutes, seconds, video_duration)
# Out:
# 0 15 42 942.0
# 0 17 30 1050.0
# 0 18 29 1109.0
# 0 15 17 917.0
# 0 14 18 858.0
# 0 17 51 1071.0
# 0 16 48 1008.0
# 0 14 32 872.0
# 0 17 21 1041.0
